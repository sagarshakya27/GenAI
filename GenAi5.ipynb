# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarshakya27/GenAI/blob/main/GenAi5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

print("Simple Attention Mechanism")

encoder_outputs = np.array([
    [0.1, 0.2],
    [0.5, 0.3],
    [0.1, 0.8],
    [0.9, 0.1]
])

print(f"\nEncoder Outputs (4 words, 2 features each):\n{encoder_outputs}")

decoder_hidden_state = np.array([0.7, 0.4])

print(f"\nDecoder Hidden State (What we are looking for): {decoder_hidden_state}")

alignment_scores = np.dot(encoder_outputs, decoder_hidden_state)

print(f"\nAlignment Scores (similarity of each encoder output to decoder state): {alignment_scores}")

def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)

attention_weights = softmax(alignment_scores)

print(f"\nAttention Weights (how much to 'pay attention' to each word): {attention_weights}")

print(
    "\nNotice that the word 'student' (index 3) got a higher weight, "
    "meaning it's more relevant to 'learning'."
)

context_vector = np.sum(
    encoder_outputs * attention_weights[:, np.newaxis],
    axis=0
)

print(
    f"\nContext Vector (weighted sum of encoder outputs, "
    f"'paying attention'): {context_vector}"
)

print("\n--- How it works ---")
# Out:
# Simple Attention Mechanism
#
# Encoder Outputs (4 words, 2 features each):
# [[0.1 0.2]
#  [0.5 0.3]
#  [0.1 0.8]
#  [0.9 0.1]]
#
# Decoder Hidden State (What we are looking for): [0.7 0.4]
#
# Alignment Scores (similarity of each encoder output to decoder state): [0.15 0.47 0.39 0.67]
#
# Attention Weights (how much to 'pay attention' to each word): [0.18760302 0.25835333 0.23849018 0.31555347]
#
# Notice that the word 'student' (index 3) got a higher weight, meaning it's more relevant to 'learning'.
#
# Context Vector (weighted sum of encoder outputs, 'paying attention'): [0.45578411 0.33737409]
#
# --- How it works ---
